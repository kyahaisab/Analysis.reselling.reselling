# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\hp\Desktop\STOCKX PRICES\Combined Table.xlsx')
df
# Out:
#                                                   Name  \
# 0             Nike Dunk Low Brazil (2020) - CU1727-700
# 1              Nike Air Max 90 Green Camo - CW4039-300
# 2    Nike Air Max 90 Reverse Duck Camo (2020) - CW6...
# 3        Nike LD Waffle Sacai White Nylon - BV0073-101
# 4    Nike Air Max 2 Light Atmos - CJ6200-001/BV7406...
# ..                                                 ...
# 195  adidas Yeezy Boost 350 V2 Cloud White (Reflect...
# 196  adidas Yeezy Boost 350 V2 Yeshaya (Reflective)...
# 197  adidas Human Race NMD Pharrell Holi Festival (...
# 198       adidas Yeezy Powerphase Clear Brown - FV6126
# 199  adidas Ultra Boost 4.0 Game of Thrones Nights ...
#
#                                            Stockx Link Condition  \
# 0         https://stockx.com/nike-dunk-low-brazil-2020       New
# 1    https://stockx.com/nike-air-max-90-duck-camo-volt       New
# 2    https://stockx.com/nike-air-max-90-reverse-duc...       New
# ...

# %%
df.corr()
# Out:
#                                  Retail Price  52week High  52week Low  \
# Retail Price                         1.000000     0.158275    0.148211
# 52week High                          0.158275     1.000000    0.982445
# 52week Low                           0.148211     0.982445    1.000000
# Volatility                          -0.030389     0.125277    0.119960
# No of Sales                          0.164964    -0.079011   -0.081345
# Price Premium                       -0.162037     0.662243    0.690293
# Average Sales Price                  0.120576     0.989168    0.998204
# Trading Low                          0.118230     0.974402    0.950233
# Trading High                         0.111722     0.986949    0.973206
# Price (US $)                         0.077725     0.525426    0.428557
# Followers                           -0.257676    -0.074177   -0.055025
# Feedback #1 (Item as described)     -0.151030    -0.083113   -0.064696
# ...

# %%
df.describe()
# Out:
#        Retail Price   52week High    52week Low  Volatility   No of Sales  \
# count    194.000000    199.000000    195.000000  198.000000    199.000000
# mean     193.469072   1182.804020    413.415385   15.913636   5516.130653
# std       55.279802   2795.292458   1559.704699    8.934509   9813.239908
# min       65.000000    149.000000     25.000000    2.700000      2.000000
# 25%      160.000000    422.500000    105.500000    9.600000    302.000000
# 50%      200.000000    625.000000    175.000000   14.100000   2452.000000
# 75%      220.000000   1000.000000    250.000000   19.975000   6703.500000
# max      350.000000  34000.000000  20002.000000   54.300000  87525.000000
#
#        Price Premium  Average Sales Price   Trading Low  Trading High  \
# count     163.000000           199.000000    199.000000    199.000000
# mean      252.069939           654.085427    562.924623    823.472362
# std       664.436527          2133.106133   1313.778143   2204.591347
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002C533A3BA90>,
# ...
#       dtype=object)

# %%
plt.plot(df['Average Sales Price'], df['No of Sales'])
plt.show()

# %%
plt.plot(df['Volatility'], df['No of Sales'])

# %%
plt.plot(df['Price Premium'], df['No of Sales'])

# %%
plt.plot(df['Trading Low'], df['No of Sales'])

# %%
plt.plot(df['Trading High'], df['No of Sales'])

# %%
plt.plot(range(200), df['52week High'])

# %%
plt.plot(range(200), df['52week Low'])

# %%
plt.plot(range(200), df['No of Sales'])

# %%
plt.plot(range(200), df['Volatility'])

# %%
plt.plot(df['Average Sales Price'], df['Price (US $)'])

# %%
plt.plot(df['Release Date'], df['Volatility'])

# %%
plt.plot(df['No of Sales'], df['Price Premium'])
